jpeg
#  extracting: diFatigue-dataset/Non-Fatigue/RightEye/98.jpeg
#  extracting: diFatigue-dataset/Non-Fatigue/RightEye/99.jpeg

# %%
from PIL import Image
from io import BytesIO
import os


fat=[]
non_fat=[]

# im = Image.open(BytesIO(uploaded['Image_file_name.jpg']))
items = os.listdir('/content/diFatigue-dataset/Fatigue/LeftEye')
for item in items:
  s=''
  if item == ".DS_Store":
    continue
  im = Image.open('/content/diFatigue-dataset/Fatigue/LeftEye/'+item)
  pix_val = list(im.getdata())
  s += ' '.join(str(e) for e in pix_val)
  s += ' '
  im = Image.open('/content/diFatigue-dataset/Fatigue/RightEye/'+item)
  pix_val = list(im.getdata())
  s += ' '.join(str(e) for e in pix_val)  
  s += ' '
  im = Image.open('/content/diFatigue-dataset/Fatigue/Mouth/'+item)
  im = im.resize((64,32),Image.ANTIALIAS)
  pix_val = list(im.getdata())
  s += ' '.join(str(e) for e in pix_val)
  fat.append(s)

items = os.listdir('/content/diFatigue-dataset/Non-Fatigue/LeftEye')
for item in items:
  s=''
  if item == ".DS_Store":
    continue
  im = Image.open('/content/diFatigue-dataset/Non-Fatigue/LeftEye/'+item)
  pix_val = list(im.getdata())
  s += ' '.join(str(e) for e in pix_val)
  s += ' '
  im = Image.open('/content/diFatigue-dataset/Non-Fatigue/RightEye/'+item)
  pix_val = list(im.getdata())
  s += ' '.join(str(e) for e in pix_val) 
  #print(len(s.split(' ')))
  s += ' '     
  im = Image.open('/content/diFatigue-dataset/Non-Fatigue/Mouth/'+item)
  im = im.resize((64,32),Image.ANTIALIAS)
  pix_val = list(im.getdata())  
  s += ' '.join(str(e) for e in pix_val)
  non_fat.append(s)
  #print(len(s.split(' ')))
    
print(len(non_fat[1].split(' ')))
print(len(fat[1].split(' ')))
# Out:
# 6144
# 6144

# %%
import pandas as pd
temp=1
temp1=0
df = pd.DataFrame(data={"pixel": fat,  "label":  temp })
df1 = pd.DataFrame(data={"pixel": non_fat,  "label":  temp1 })
frames = [df, df1]
result = pd.concat(frames)
print(df)
print(df1)
print(result)

result.to_csv("./file1.csv", sep=',',index=False)
print(result.shape)
# Out:
#                                                  pixel  label
# 0    67 73 79 84 89 91 92 95 96 97 98 99 101 104 10...      1
# 1    118 118 118 117 115 113 112 111 113 112 110 10...      1
# 2    112 111 109 108 107 106 107 109 110 109 112 11...      1
# 3    173 162 161 163 160 156 150 138 126 118 112 10...      1
# 4    122 121 119 117 117 116 114 111 112 113 113 11...      1
# ..                                                 ...    ...
# 555  129 127 121 115 112 114 117 117 118 118 117 11...      1
# 556  50 54 62 70 72 71 69 69 64 55 45 40 41 46 57 6...      1
# 557  92 91 89 87 85 86 86 82 78 76 74 75 77 79 82 8...      1
# 558  121 121 120 119 118 117 116 114 113 111 109 10...      1
# 559  167 163 158 156 158 162 167 170 171 170 169 16...      1
#
# [560 rows x 2 columns]
#                                                  pixel  label
# 0    123 125 126 126 127 128 132 137 140 140 141 14...      0
# 1    40 48 58 65 60 54 63 65 50 36 33 39 51 63 70 7...      0
# 2    175 172 166 146 126 167 173 178 179 172 162 16...      0
# 3    64 64 65 65 65 67 68 68 73 74 75 77 77 75 75 7...      0
# 4    34 38 42 46 48 51 55 57 60 62 64 66 69 73 76 7...      0
# ..                                                 ...    ...
# 555  71 76 78 70 56 45 43 45 42 31 28 46 73 87 86 8...      0
# 556  130 129 129 128 129 130 133 135 139 142 143 14...      0
# 557  178 178 179 180 181 181 181 180 181 182 182 18...      0
# 558  39 43 46 49 52 54 55 58 59 61 63 66 70 72 73 7...      0
# 559  158 156 152 147 142 138 137 137 135 135 136 13...      0
#
# [560 rows x 2 columns]
#                                                  pixel  label
# 0    67 73 79 84 89 91 92 95 96 97 98 99 101 104 10...      1
# 1    118 118 118 117 115 113 112 111 113 112 110 10...      1
# 2    112 111 109 108 107 106 107 109 110 109 112 11...      1
# 3    173 162 161 163 160 156 150 138 126 118 112 10...      1
# 4    122 121 119 117 117 116 114 111 112 113 113 11...      1
# ..                                                 ...    ...
# 555  71 76 78 70 56 45 43 45 42 31 28 46 73 87 86 8...      0
# 556  130 129 129 128 129 130 133 135 139 142 143 14...      0
# 557  178 178 179 180 181 181 181 180 181 182 182 18...      0
# 558  39 43 46 49 52 54 55 58 59 61 63 66 70 72 73 7...      0
# 559  158 156 152 147 142 138 137 137 135 135 136 13...      0
#
# [1120 rows x 2 columns]
# (1120, 2)

# %%
print(len(non_fat))
# Out:
# 560

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import math
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout, BatchNormalization, LeakyReLU, Activation
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.utils import np_utils

# %%
df = pd.read_csv('/content/file1.csv')
print(df.shape)
df.head()
# Out:
# (1120, 2)
#                                                pixel  label
# 0  67 73 79 84 89 91 92 95 96 97 98 99 101 104 10...      1
# 1  118 118 118 117 115 113 112 111 113 112 110 10...      1
# 2  112 111 109 108 107 106 107 109 110 109 112 11...      1
# 3  173 162 161 163 160 156 150 138 126 118 112 10...      1
# 4  122 121 119 117 117 116 114 111 112 113 113 11...      1

# %%
img_arr = df.pixel.apply(lambda x : np.array(str(x).split(' ')).reshape(64,32,3).astype('float32'))
img_arr_f = np.stack(img_arr,axis=0)
print(img_arr_f.shape)
# img=[]
# img_arr1 = df.Right_Eye.apply(lambda x : np.array(str(x).split(' ')).reshape(64,32,1).astype('float32'))
# print(img_arr1.shape)
# img_arr2 = df.Left_Eye.apply(lambda x : np.array(str(x).split(' ')).reshape(64,32,1).astype('float32'))
# img_arr3 = df.Mouth.apply(lambda x : np.array(str(x).split(' ')[0:2048]).reshape(64,32,1).astype('float32'))
# # img.append(img_arr1)
# # img.append(img_arr2)
# # img.append(img_arr3)
# print(df.head())
# img_arr_f = np.concatenate((img_arr1,img_arr2,img_arr3))
# print(img_arr_f.shape)
# img_array1 = np.stack(img_arr1, axis=0)
# img_array2 = np.stack(img_arr2, axis=0)
# img_array3 = np.stack(img_arr3, axis=0)
# img_arr = np.stack(img_arr_f,axis=0)
# print(img_arr.shape)
# Out:
# (1120, 64, 32, 3)

# %%
le = LabelEncoder()
img_labels = le.fit_transform(df.label)
img_labels = np_utils.to_categorical(img_labels)
img_labels.shape
# Out:
# (1120, 2)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(img_arr_f, img_labels,
                                                    shuffle=True,stratify=img_labels,
                                                    test_size=0.1, random_state=42)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((1008, 64, 32, 3), (112, 64, 32, 3), (1008, 2), (112, 2))

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]
num_classes = y_train.shape[1]

# %%
# Normalizing results, as neural networks are very sensitive to unnormalized data.
X_train = X_train / 255.
X_valid = X_valid / 255.

# %%
def build_net(optim):
    """
    This is a Deep Convolutional Neural Network (DCNN). For generalization purpose I used dropouts in regular intervals.
    I used `ELU` as the activation because it avoids dying relu problem but also performed well as compared to LeakyRelu
    atleast in this case. `he_normal` kernel initializer is used as it suits ELU. BatchNormalization is also used for better
    results.
    """
    net = Sequential(name='DCNN')

    net.add(
        Conv2D(
            filters=64,
            kernel_size=(5,5),
            input_shape=(img_width, img_height, img_depth),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_1'
        )
    )
    net.add(BatchNormalization(name='batchnorm_1'))
    net.add(
        Conv2D(
            filters=64,
            kernel_size=(5,5),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_2'
        )
    )
    net.add(BatchNormalization(name='batchnorm_2'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
    net.add(Dropout(0.4, name='dropout_1'))

    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_3'
        )
    )
    net.add(BatchNormalization(name='batchnorm_3'))
    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_4'
        )
    )
    net.add(BatchNormalization(name='batchnorm_4'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
    net.add(Dropout(0.4, name='dropout_2'))

    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_5'
        )
    )
    net.add(BatchNormalization(name='batchnorm_5'))
    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_6'
        )
    )
    net.add(BatchNormalization(name='batchnorm_6'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
    net.add(Dropout(0.5, name='dropout_3'))

    net.add(Flatten(name='flatten'))
        
    net.add(
        Dense(
            128,
            activation='elu',
            kernel_initializer='he_normal',
            name='dense_1'
        )
    )
    net.add(BatchNormalization(name='batchnorm_7'))
    
    net.add(Dropout(0.6, name='dropout_4'))
    
    net.add(
        Dense(
            num_classes,
            activation='softmax',
            name='out_layer'
        )
    )
    
    net.compile(
        loss='categorical_crossentropy',
        optimizer=optim,
        metrics=['accuracy']
    )
    
    net.summary()
    
    return net

# %%
"""
I used two callbacks one is `early stopping` for avoiding overfitting training data
and other `ReduceLROnPlateau` for learning rate.
"""

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00005,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
    early_stopping,
    lr_scheduler,
]

# %%
# As the data in hand is less as compared to the task so ImageDataGenerator is good to go.
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
)
train_datagen.fit(X_train)

# %%
batch_size = 32 #batch size of 32 performs the best.
epochs = 100
optims = [
    optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, name='Nadam'),
    optimizers.Adam(0.001),
]

# I tried both `Nadam` and `Adam`, the difference in results is not different but I finally went with Nadam as it is more popular.
model = build_net(optims[1]) 
history = model.fit_generator(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data=(X_valid, y_valid),
    steps_per_epoch=len(X_train) / batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Model: "DCNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 32, 64)        4864
# _________________________________________________________________
# batchnorm_1 (BatchNormalizat (None, 64, 32, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 32, 64)        102464
# _________________________________________________________________
# batchnorm_2 (BatchNormalizat (None, 64, 32, 64)        256
# _________________________________________________________________
# maxpool2d_1 (MaxPooling2D)   (None, 32, 16, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 16, 128)       73856
# _________________________________________________________________
# batchnorm_3 (BatchNormalizat (None, 32, 16, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 16, 128)       147584
# _________________________________________________________________
# batchnorm_4 (BatchNormalizat (None, 32, 16, 128)       512
# _________________________________________________________________
# maxpool2d_2 (MaxPooling2D)   (None, 16, 8, 128)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 8, 128)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 8, 256)        295168
# _________________________________________________________________
# batchnorm_5 (BatchNormalizat (None, 16, 8, 256)        1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 8, 256)        590080
# _________________________________________________________________
# batchnorm_6 (BatchNormalizat (None, 16, 8, 256)        1024
# _________________________________________________________________
# maxpool2d_3 (MaxPooling2D)   (None, 8, 4, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1048704
# _________________________________________________________________
# batchnorm_7 (BatchNormalizat (None, 128)               512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 2)                 258
# =================================================================
# Total params: 2,267,074
# Trainable params: 2,265,026
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 1.0162 - accuracy: 0.6660WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 41ms/step - loss: 0.9967 - accuracy: 0.6696 - val_loss: 9.6448 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.6637 - accuracy: 0.7202WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 32ms/step - loss: 0.6637 - accuracy: 0.7202 - val_loss: 2.2364 - val_accuracy: 0.5625 - lr: 0.0010
# Epoch 3/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.7520WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.6260 - accuracy: 0.7520 - val_loss: 1.6703 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 4/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 30/31 [===========================>..] - ETA: 0s - loss: 0.5520 - accuracy: 0.7733WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 35ms/step - loss: 0.5377 - accuracy: 0.7768 - val_loss: 0.6214 - val_accuracy: 0.7679 - lr: 0.0010
# Epoch 5/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.4329 - accuracy: 0.8095WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.4329 - accuracy: 0.8095 - val_loss: 0.7944 - val_accuracy: 0.5536 - lr: 0.0010
# Epoch 6/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.4384 - accuracy: 0.8197WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.4338 - accuracy: 0.8234 - val_loss: 1.0302 - val_accuracy: 0.5714 - lr: 0.0010
# Epoch 7/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.3566 - accuracy: 0.8433WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 34ms/step - loss: 0.3566 - accuracy: 0.8433 - val_loss: 1.5502 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 8/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.3814 - accuracy: 0.8330WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 34ms/step - loss: 0.3871 - accuracy: 0.8323 - val_loss: 0.1742 - val_accuracy: 0.9286 - lr: 0.0010
# Epoch 9/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.8750WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.2861 - accuracy: 0.8750 - val_loss: 1.8672 - val_accuracy: 0.5357 - lr: 0.0010
# Epoch 10/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.3041 - accuracy: 0.8648WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.3080 - accuracy: 0.8651 - val_loss: 0.6791 - val_accuracy: 0.8036 - lr: 0.0010
# Epoch 11/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.2341 - accuracy: 0.8965WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.2296 - accuracy: 0.8988 - val_loss: 1.2912 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 12/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.2426 - accuracy: 0.9037WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 34ms/step - loss: 0.2442 - accuracy: 0.9018 - val_loss: 2.1139 - val_accuracy: 0.5982 - lr: 0.0010
# Epoch 13/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9276WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1986 - accuracy: 0.9276 - val_loss: 0.1592 - val_accuracy: 0.9196 - lr: 0.0010
# Epoch 14/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 30/31 [===========================>..] - ETA: 0s - loss: 0.1949 - accuracy: 0.9216WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1897 - accuracy: 0.9246 - val_loss: 0.4835 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 15/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9048WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.2102 - accuracy: 0.9048 - val_loss: 1.7630 - val_accuracy: 0.6250 - lr: 0.0010
# Epoch 16/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1725 - accuracy: 0.9293WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1718 - accuracy: 0.9306 - val_loss: 0.3125 - val_accuracy: 0.9018 - lr: 5.0000e-04
# Epoch 17/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9375WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 36ms/step - loss: 0.1429 - accuracy: 0.9375 - val_loss: 0.1708 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 18/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.9464WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 34ms/step - loss: 0.1369 - accuracy: 0.9464 - val_loss: 0.1205 - val_accuracy: 0.9554 - lr: 5.0000e-04
# Epoch 19/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1218 - accuracy: 0.9549WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 32ms/step - loss: 0.1209 - accuracy: 0.9554 - val_loss: 0.0960 - val_accuracy: 0.9375 - lr: 5.0000e-04
# Epoch 20/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9534WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 34ms/step - loss: 0.1344 - accuracy: 0.9534 - val_loss: 0.0566 - val_accuracy: 0.9911 - lr: 5.0000e-04
# Epoch 21/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9623WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1033 - accuracy: 0.9623 - val_loss: 0.0503 - val_accuracy: 0.9911 - lr: 5.0000e-04
# Epoch 22/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9464WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 34ms/step - loss: 0.1200 - accuracy: 0.9464 - val_loss: 0.0637 - val_accuracy: 0.9643 - lr: 5.0000e-04
# Epoch 23/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9518WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 32ms/step - loss: 0.1255 - accuracy: 0.9524 - val_loss: 0.1631 - val_accuracy: 0.9196 - lr: 5.0000e-04
# Epoch 24/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1303 - accuracy: 0.9529WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 34ms/step - loss: 0.1352 - accuracy: 0.9504 - val_loss: 0.1066 - val_accuracy: 0.9464 - lr: 5.0000e-04
# Epoch 25/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1243 - accuracy: 0.9477WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1225 - accuracy: 0.9484 - val_loss: 0.0812 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 26/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1123 - accuracy: 0.9539WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1094 - accuracy: 0.9554 - val_loss: 0.1160 - val_accuracy: 0.9464 - lr: 5.0000e-04
# Epoch 27/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.9544WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/31 [==============================] - 1s 35ms/step - loss: 0.1183 - accuracy: 0.9544 - val_loss: 0.1069 - val_accuracy: 0.9821 - lr: 5.0000e-04
# Epoch 28/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1009 - accuracy: 0.9652WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1016 - accuracy: 0.9653 - val_loss: 0.1447 - val_accuracy: 0.9464 - lr: 2.5000e-04
# Epoch 29/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9549WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1034 - accuracy: 0.9534 - val_loss: 0.1002 - val_accuracy: 0.9554 - lr: 2.5000e-04
# Epoch 30/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9524WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 32/31 [==============================] - 1s 33ms/step - loss: 0.1181 - accuracy: 0.9524 - val_loss: 0.0736 - val_accuracy: 0.9643 - lr: 2.5000e-04
# Epoch 31/100
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 31/31 [============================>.] - ETA: 0s - loss: 0.1246 - accuracy: 0.9621WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Restoring model weights from the end of the best epoch.
# 32/31 [==============================] - 1s 35ms/step - loss: 0.1244 - accuracy: 0.9613 - val_loss: 0.0992 - val_accuracy: 0.9375 - lr: 2.5000e-04
# Epoch 00031: early stopping

# %%
model_yaml = model.to_yaml()
with open("model.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
    
model.save("model_new_small.h5")

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#   inflating: data/Img36.jpg
#   inflating: data/Img42.jpg
#   inflating: data/Img48.jpg

# %%
from PIL import Image
import os
import numpy as np
from keras.preprocessing import image 
from skimage.transform import resize
# from keras.models import load_model
from tensorflow import keras




# print("--------------------------------")
fat=[]
# items = os.listdir('C:\iSmile TEch\Drowsiness Detection\diFatigue-dataset.tar\data')
# items = os.litdir('/content/data')
items= ['1.jpg','2.jpg','3.jpg']
# print(items)

mapper={
    1:"Fatigue",
    0:"Non-Fatigue"
}


s=''
for item in items:
  im = Image.open('/content/data/'+item).convert('LA')
  im = im.resize((64,32),Image.ANTIALIAS)
  pix_val = list(im.getdata())  
  pix_val_flat = [sets[0] for sets in pix_val]
  s += ' '.join(str(x) for x in pix_val_flat)
  if(item == '3.jpg'):
    break
  s += ' '

fat.append(s)
# print(len(fat[0].split(' ')))

MODEL_PATH = r'/content/model_f.h5'

model =  keras.models.load_model(MODEL_PATH)


temp = np.array(fat[0].split(' ')).reshape(64,32,3).astype('float32')
#img_arr_f = np.stack(img_arr,axis=0)

# print(temp.shape)
temp = temp / 255
# print(temp)
print(mapper[model.predict_classes(temp.reshape(1,64,32,3))[0]])
# Out:
# Non-Fatigue

# %%
# !apt install unixodbc-dev
# !pip install pyodbc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   unixodbc-dev
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 217 kB of archives.
# After this operation, 1,779 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 unixodbc-dev amd64 2.3.4-1.1ubuntu3 [217 kB]
# Fetched 217 kB in 1s (361 kB/s)
# Selecting previously unselected package unixodbc-dev:amd64.
# (Reading database ... 144465 files and directories currently installed.)
# Preparing to unpack .../unixodbc-dev_2.3.4-1.1ubuntu3_amd64.deb ...
# Unpacking unixodbc-dev:amd64 (2.3.4-1.1ubuntu3) ...
# Setting up unixodbc-dev:amd64 (2.3.4-1.1ubuntu3) ...
# Collecting pyodbc
#   Using cached https://files.pythonhosted.org/packages/81/0d/bb08bb16c97765244791c73e49de9fd4c24bb3ef00313aed82e5640dee5d/pyodbc-4.0.30.tar.gz
# Building wheels for collected packages: pyodbc
#   Building wheel for pyodbc (setup.py) ... done
#   Created wheel for pyodbc: filename=pyodbc-4.0.30-cp36-cp36m-linux_x86_64.whl size=272715 sha256=08c8fd664a0456584550b447879a9e2cc279d2a0f3fed41816fc5b16ade57513
#   Stored in directory: /root/.cache/pip/wheels/4a/02/ba/6b495fec7cb127583a769a74f3ba91eb700d73e25fbb5ba09b
# Successfully built pyodbc
# Installing collected packages: pyodbc
# Successfully installed pyodbc-4.0.30

# %%
# !sudo su
# !wget https://gallery.technet.microsoft.com/ODBC-Driver-13-for-Ubuntu-b87369f0/file/154097/2/installodbc.sh
# !sh installodbc.sh
# Out:
# bash: cannot set terminal process group (120): Inappropriate ioctl for device
# bash: no job control in this shell
# root@36947d48670a:/content#
# root@36947d48670a:/content#
# root@36947d48670a:/content#
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-75523b3a0afb> in <module>()
# ----> 1 get_ipython().system('sudo su')
#       2 get_ipython().system('wget https://gallery.technet.microsoft.com/ODBC-Driver-13-for-Ubuntu-b87369f0/file/154097/2/installodbc.sh')
#       3 get_ipython().system('sh installodbc.sh')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     439   shell.user_ns['_exit_code'] = result.returncode
#     440   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     193       os.close(child_pty)
#     194
# --> 195       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     196   finally:
#     197     epoll.close()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     220   while True:
#     221     try:
# --> 222       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     223       if result is not None:
#     224         return result
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     267   output_available = False
#     268
# --> 269   events = epoll.poll()
#     270   input_events = []
#     271   for _, event in events:
#
# KeyboardInterrupt:

# %%
from PIL import Image
import os
import numpy as np
#from keras.preprocessing import image 
from skimage.transform import resize
#from keras.models import load_model
from tensorflow import keras

from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2

import pyodbc

server = 'virutal.database.windows.net' 
database = 'COVID19-db' 
username = 'Ismiledb' 
password = 'Ismile@123' 
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()

cursor.execute("SELECT TOP 1 * FROM Images ORDER BY Imageid DESC")
row=cursor.fetchone()
print("--------------------------database connectivity-----------")
#print(row[1])

value = b'' # however you get it from the db
with open("/content/the_img.jpg", "wb") as img:
  img.write(row[1])

#import base64
#with open("imageToSave.jpg", "wb") as fh:fh.write(base64.decodebytes(img))

# initialize dlib's face detector (HOG-based) and then create
# the facial landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

# load the input image, resize it, and convert it to grayscale
image = cv2.imread('/content/the_img.jpg')
image = imutils.resize(image, width=500)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# detect faces in the grayscale image
rects = detector(gray, 1)
c=1
# loop over the face detections
for (i, rect) in enumerate(rects):
	# determine the facial landmarks for the face region, then
	# convert the landmark (x, y)-coordinates to a NumPy array
	shape = predictor(gray, rect)
	shape = face_utils.shape_to_np(shape)

	# loop over the face parts individually
	for (name, (i, j)) in face_utils.FACIAL_LANDMARKS_IDXS.items():
		# clone the original image so we can draw on it, then
		# display the name of the face part on the image
		clone = image.copy()
		cv2.putText(clone, name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX,
			0.7, (0, 0, 255), 2)

		# loop over the subset of facial landmarks, drawing the
		# specific face part
		for (x, y) in shape[i:j]:
			cv2.circle(clone, (x, y), 1, (0, 0, 255), -1)

		# extract the ROI of the face region as a separate image
		(x, y, w, h) = cv2.boundingRect(np.array([shape[i:j]]))
		roi = image[y-15:y + h+15, x-15:x + w+15]
		roi = imutils.resize(roi, width=250, inter=cv2.INTER_CUBIC)
		print(x, y, w, h)
		# show the particular face part
		#cv2.imshow("ROI", roi)
		#cv2.imshow("Image", clone)
		#cv2.waitKey(0)
		cv2.imwrite("images/Img"+str(i)+".jpg",roi)

	# visualize all facial landmarks with a transparent overlay
	#output = face_utils.visualize_facial_landmarks(image, shape)
	#cv2.imshow("Image", output)
	#cv2.waitKey(0)





print("--------------------------------")
fat=[]
# items = os.listdir('C:\iSmile TEch\Drowsiness Detection\diFatigue-dataset.tar\data')
# items = os.litdir('/content/data')
items= ['Img36.jpg','Img42.jpg','Img48.jpg']
# print(items)

mapper={
    1:"Fatigue",
    0:"Non-Fatigue"
}


s=''
for item in items:
  im = Image.open('/content/'+item).convert('LA')
  im = im.resize((64,32),Image.ANTIALIAS)
  pix_val = list(im.getdata())  
  pix_val_flat = [sets[0] for sets in pix_val]
  s += ' '.join(str(x) for x in pix_val_flat)
  if(item == 'Img48.jpg'):
    break
  s += ' '

fat.append(s)
# print(len(fat[0].split(' ')))

MODEL_PATH = r'model_f.h5'

model =  keras.models.load_model(MODEL_PATH)


temp = np.array(fat[0].split(' ')).reshape(64,32,3).astype('float32')
#img_arr_f = np.stack(img_arr,axis=0)

# print(temp.shape)
temp = temp / 255
# print(temp)
print(mapper[model.predict_classes(temp.reshape(1,64,32,3))[0]])
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-11-0675c0c7f040> in <module>()
#      20 username = 'Ismiledb'
#      21 password = 'Ismile@123'
# ---> 22 cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
#      23 cursor = cnxn.cursor()
#      24
#
# Error: ('01000', "[01000] [unixODBC][Driver Manager]Can't open lib 'SQL Server' : file not found (0) (SQLDriverConnect)")
